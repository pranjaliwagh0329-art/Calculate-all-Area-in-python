# %% [markdown]
# ## Area of All by using simple math formulas

# %% [markdown]
# #### Area of circle

# %%
a=4
Area=3.14*a*a
Area
# Out:
# 50.24

# %%
R=8
A=3.14*R*R
A
# Out:
# 200.96

# %%
### Circumference
s=5
Cir=2*3.13*s
Cir
# Out:
# 31.299999999999997

# %% [markdown]
# #### Area of square

# %%
H=24
Area=H*H
Area
# Out:
# 576

# %%
G=50
Sq=G**2
Sq
# Out:
# 2500

# %% [markdown]
# ### Area of rectanle

# %%
G=4
H=8
Rec=G*H
Rec
# Out:
# 32

# %%
o=67
p=34
Rec=o*p;Rec
# Out:
# 2278

# %% [markdown]
# ### Area of triangle

# %%
B=5
H=9
Tri=0.5*B*H
Tri
# Out:
# 22.5

# %%
D=45
P=88
Tri=D*P*0.5
Tri
# Out:
# 1980.0

# %% [markdown]
# ### Area of parallelogram

# %%
base=78
height=56
P=base*height
P
# Out:
# 4368

# %%
K=13
L=47
P=K*L
P
# Out:
# 611
